# %% [markdown]
# <a href="https://colab.research.google.com/github/issaq96/Prediction-of-Product-Sales/blob/main/prediction_of_products_sales.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # prediction of Product Sales
# * -Issa Qahoush

# %% [markdown]
# ## "Project Overview"

# %% [markdown]
# ## "Load and Inspect Data"

# %% [markdown]
# ## "Clean Data"

# %% [markdown]
# ## "Exploratory Data Anlysis"

# %% [markdown]
# ## "Feature Inspection"
